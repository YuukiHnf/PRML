# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def func(train_data, t, loop):
  def perceptron(train_data,t, loop):
    count = 0
    eta = 0.05
    w = np.array([0.5,0.5,1.0])
    i = 0

    while count < loop:
      if t[i] * w@np.insert(X_train[i,:],0,1) < 0:
        w += -eta * np.dot(w,np.insert(X_train[i,:],0,1))
        count = 0
        i+=1
      else:
        count += 1
        i+=1

      if i == len(train_data):
        i = 0
    return w

  w = perceptron(train_data,t,loop)
  plt.scatter(x_red, y_red,color="r", marker='x')
  plt.scatter(x_blue, y_blue, color="b", marker="x")
  x_line = np.linspace(-1,1,1000)
  y_line = -w[1]/w[2] * x_line - w[0] / w[2]
  plt.plot(x_line, y_line)
  plt.xlim(-1,1)
  plt.ylim(-1,1)
  plt.title(f"Perceptron-{loop}")
  plt.show()

# %%
mu_blue = [-0.5, 0.3]
mu_red = [0.5, -0.3]

cov = [[0.08, 0.06], [0.06, 0.08]]

x_blue = [-0.85, -0.8, -0.5, -0.4, -0.1]
y_blue = [0.6,0.95, 0.62, 0.7, -0.1]
Data_blue = np.vstack((x_blue, y_blue)).T
blue_label = np.ones(5)

x_red = [0.2, 0.4, 0.45, 0.6, 0.95]
y_red = [0.7, -0.5, 0.4, -0.9, 0.97]
Data_red = np.vstack((x_red, y_red)).T
red_label = -np.ones(5)

X_train = np.r_[Data_blue,Data_red]
label = np.r_[blue_label, red_label].T

N = len(x_blue) + len(x_red)
for loop in [N-9, N-6, N-3, N]:
  func(X_train, label, loop)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-f5c6f21c3e2b> in <module>()
#      19 N = len(x_blue) + len(x_red)
#      20 for loop in [N-9, N-6, N-3, N]:
# ---> 21   func(X_train, label, loop)
#
# <ipython-input-68-4831a67476fc> in func(train_data, t, loop)
#      19     return w
#      20
# ---> 21   w = perceptron(train_data,t,loop)
#      22   plt.scatter(x_red, y_red,color="r", marker='x')
#      23   plt.scatter(x_blue, y_blue, color="b", marker="x")
#
# <ipython-input-68-4831a67476fc> in perceptron(train_data, t, loop)
#       7
#       8     while count < loop:
# ----> 9       if t[i] * w@np.insert(X_train[i,:],0,1) < 0:
#      10         w += -eta * np.dot(w,np.insert(X_train[i,:],0,1))
#      11         count = 0
#
# <__array_function__ internals> in insert(*args, **kwargs)
#
# ...
